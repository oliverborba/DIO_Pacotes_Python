# %%
from image_processing_pack import processing
from image_processing_pack import utils

# %%
image1 = utils.read_image("C:/Users/lucas/Documents/simple-package-template-master/images/green_forest.jpg")
image2 = utils.read_image("C:/Users/lucas/Documents/simple-package-template-master/images/autumn_forest.jpg")

# %%
utils.plot_image(image1)
utils.plot_image(image2)

# %%
result_image = processing.transfer_histogram(image1, image2)
utils.plot_result(image1, image2, result_image)
